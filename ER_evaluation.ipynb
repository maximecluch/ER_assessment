# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import connected_components
from itertools import compress, product
from entity_resolution_evaluation.evaluation import evaluate
#https://pypi.org/project/entity-resolution-evaluation/

def generate_combinations(_columns):
    ''' generate (2^N)-1 combinations'''
    return [list(compress(_columns,mask)) for mask in product(*[[0,1]]*len(_columns))][1:]

def create_matrices(_df, _columns):
    ''' build a dictionary with:
    - key: column name
    - value: the matrix of similarity between entities associated to this column'''
    _matrices= {}
    for _column in _columns:
        _tmp = pd.get_dummies(_df[_column], columns=[_column], sparse=True)
        _tmp = csr_matrix(_tmp)
        _tmp = np.dot(_tmp, _tmp.T)
        #_tmp.setdiag(0)
        #_tmp.eliminate_zeros()
        _tmp = _tmp.toarray()
        #np.fill_diagonal(_tmp,0)
        _matrices[_column] = _tmp
    return _matrices

def set_partition(_operation):    
    #Find connected elements in the graph and output label of clusters
    n_components, labels = connected_components(csgraph=_operation, directed=False, return_labels=True)

    #Build the partition
    partition = set(pd.Series(range(len(labels))).groupby(labels).apply(frozenset))
    
    #return set(_df.reset_index().groupby([0])['index'].apply(frozenset).tolist())
    return partition

def generate_new_entity(_dict_matrices, operand="OR"):
    if operand=="AND":
        operation = 1
        for m in _dict_matrices.values():
            operation *= m
    elif operand=="OR":
        # define the resolution operations Usage:  OR -> + , AND -> *
        #operation = _dict_matrices['name_consignee'] * _dict_matrices['NLP_stem']
        operation = sum(_dict_matrices.values())
    else:
        operation = sum(_dict_matrices.values())
    
    #return _df[_columns].apply(lambda x: "@".join(x), axis=1)
    return csr_matrix(operation)



def resolve(_dict_matrices, operand="OR"):
    operation = generate_new_entity(_dict_matrices, operand)
    return set_partition(operation)

# %%
goldenER = pd.read_csv("ER-Golden-50000.tsv", sep="\t")[:1000]

golden_dict_matrices = create_matrices(goldenER, ["name_consignee"])
consignee_goldenER = resolve(golden_dict_matrices, operand="AND")

# %%
goldenER
# Out:
#      identifier                     name_consignee      address_1_consignee  \
# 0     202001022                      WOOT SERVICES        1601 ESTES AVENUE
# 1     202001029                IMPERIAL FOOD, INC.           475-A BLOY ST.
# 2     202001031               CLIPSO AMERICAS INC.      200 CORPORATE DRIVE
# 3     202001035  LANGENSCHEIDT PUBLICATIONS INGRAM        1280 INGRAM DRIVE
# 4     202001036                  BOYD TECHNOLOGIES      501 PLEASANT STREET
# ..          ...                                ...                      ...
# 995  2020060333           KONECRANES AMERICA, INC.  7300 CHIPPEWA BOULEVARD
# 996  2020060377                       MOLSON COORS  V. SUAREZ ALMACEN PROMO
# 997  2020060377                       MOLSON COORS  V. SUAREZ ALMACEN PROMO
# 998  2020060377                       MOLSON COORS  V. SUAREZ ALMACEN PROMO
# 999  2020060377                       MOLSON COORS  V. SUAREZ ALMACEN PROMO
#
#           address_2_consignee               address_3_consignee  \
# 0           ELK GROVE VILLAGE                 ILLINOIS 60007 IL
# 1                 HILLSIDE US                               NaN
# 2                     SUITE 4              BLAUVELT NY 10913 US
# 3    CHAMBERSBURG PA 17202 US                               NaN
# 4             LEE MA 01238 US                               NaN
# ..                        ...                               ...
# 995       HOUSTON TX 77086 US                               NaN
# 996                       NaN  ALMACEN ANEX. 1, REXCO IND. PARK
# 997                       NaN  ALMACEN ANEX. 1, REXCO IND. PARK
# 998                       NaN  ALMACEN ANEX. 1, REXCO IND. PARK
# 999                       NaN  ALMACEN ANEX. 1, REXCO IND. PARK
#
#     address_4_consignee city_consignee zip_code_consignee  \
# 0                   NaN            NaN                NaN
# 1                   NaN            NaN                NaN
# 2                   NaN            NaN                NaN
# 3                   NaN            NaN                NaN
# 4                   NaN            NaN                NaN
# ..                  ...            ...                ...
# 995                 NaN            NaN                NaN
# 996                 NaN       GUAYNABO                NaN
# 997                 NaN       GUAYNABO                NaN
# 998                 NaN       GUAYNABO                NaN
# 999                 NaN       GUAYNABO                NaN
#
#     country_code_consignee                     name_consignor  \
# 0                      NaN                 KORNIT DIGITAL LTD
# 1                      NaN            SHAVIT TECHNOLOGIES CO.
# 2                      NaN                 CLIPSO PRODUCTIONS
# 3                      NaN   RHENUS MEDIEN GOTHA GMBH & CO.KG
# 4                      NaN                     PDM INDUSTRIES
# ..                     ...                                ...
# 995                    NaN  PFEIFER SEIL- U. HEBETECHNIK GMBH
# 996                     PR                    MICRO MATIC A/S
# 997                     PR                    MICRO MATIC A/S
# 998                     PR                    MICRO MATIC A/S
# 999                     PR                    MICRO MATIC A/S
#
#                    address_1_consignor     address_2_consignor  \
# 0    12 HAAMAL ST. POB 11781 AFEK PARK  ROSH-HAAYIN 4809246 IL
# 1                        28 HOLLAND ST        NETANYA 42221 IS
# 2                     5 RUE DE LEGLISE    VIEUX-THANN 68800 FR
# 3              LANGENSCHEIDTSTRASSE 10          GOTHA 99867 DE
# 4                                BP 34                KERISOLE
# ..                                 ...                     ...
# 995               DR.KARL LENZ STR. 66            MEMMINGEN DE
# 996                   HOLKEBJERGVEJ 48                     NaN
# 997                   HOLKEBJERGVEJ 48                     NaN
# 998                   HOLKEBJERGVEJ 48                     NaN
# 999                   HOLKEBJERGVEJ 48                     NaN
#
#     address_3_consignor address_4_consignor city_consignor zip_code_consignor  \
# 0                   NaN                 NaN            NaN                NaN
# 1                   NaN                 NaN            NaN                NaN
# 2                   NaN                 NaN            NaN                NaN
# 3                   NaN                 NaN            NaN                NaN
# 4     QUIMPERE 29393 FR                 NaN            NaN                NaN
# ..                  ...                 ...            ...                ...
# 995                 NaN                 NaN            NaN                NaN
# 996                 NaN                 NaN      ODENSE SV                NaN
# 997                 NaN                 NaN      ODENSE SV                NaN
# 998                 NaN                 NaN      ODENSE SV                NaN
# 999                 NaN                 NaN      ODENSE SV                NaN
#
#     country_code_consignor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 995                    NaN
# 996                     DK
# 997                     DK
# 998                     DK
# 999                     DK
#
# [1000 rows x 17 columns]

# %%
consignee = pd.read_csv("50000_consignee_processed.csv", dtype=str)[:1000]

column_for_resolution = ['name_consignee', 'NLP_stem',
       'NLP_phonetic_daitchmokotoff', 'NLP_phonetic_metaphone',
       'NLP_phonetic_caverphone', 'NLP_phonetic_koelner',
       'NLP_fingerprint_positionfreq', 'NLP_fingerprint_consonant',
       'NLP_fingerprint_LCCutter', 'NLP_fingerprint_BWTRLEF',
       'NLP_fingerprint_LACSS']

consignee_ALL_ER = {}

print("matrice creation...")
consignee_dict_matrices = create_matrices(consignee, column_for_resolution)

print("dictionary filter...")
#small_dict=dict_filter(large_dict, new_dict_keys)
dict_filter = lambda x, y: dict([ (i,x[i]) for i in x if i in set(y) ])

for columns in generate_combinations(column_for_resolution):
    small_dict_matrices = dict_filter(consignee_dict_matrices, columns)
    consignee_ALL_ER[" & ".join(columns)] = generate_new_entity(small_dict_matrices, operand="AND")
    consignee_ALL_ER[" | ".join(columns)] = generate_new_entity(small_dict_matrices, operand="OR")
# Out:
# matrice creation...
# dictionary filter...

# %%
consignee
# Out:
#      identifier                     name_consignee  \
# 0     202001022                      WOOT SERVICES
# 1     202001029                IMPERIAL FOOD, INC.
# 2     202001031               CLIPSO AMERICAS INC.
# 3     202001035  LANGENSCHEIDT PUBLICATIONS INGRAM
# 4     202001036                  BOYD TECHNOLOGIES
# ..          ...                                ...
# 995  2020060333           KONECRANES AMERICA, INC.
# 996  2020060377                       MOLSON COORS
# 997  2020060377                       MOLSON COORS
# 998  2020060377                       MOLSON COORS
# 999  2020060377                       MOLSON COORS
#
#                         NLP_stem  NLP_phonetic_daitchmokotoff  \
# 0                    woot servic                749744,749754
# 1              imperi food , inc                       067987
# 2             clipso america inc                487469,587469
# 3    langenscheidt public ingram                       865643
# 4                 boyd technolog                734685,735685
# ..                           ...                          ...
# 995       konecran america , inc                564964,565964
# 996                  molson coor  684644,684649,684654,684659
# 997                  molson coor  684644,684649,684654,684659
# 998                  molson coor  684644,684649,684654,684659
# 999                  molson coor  684644,684649,684654,684659
#
#     NLP_phonetic_metaphone NLP_phonetic_caverphone NLP_phonetic_koelner  \
# 0                  WTSRFSS              WTSFSS1111               387388
# 1                IMPRLFTNK              AMPRFTNK11            061753268
# 2               KLPSMRKSNK              KLPSMRKSNK           4518674868
# 3      LNJNSKTTPBLKXNSNKRM              LNKNSKTPPL    56468211542686476
# 4                 BTTXNLJS              PTKNLKS111              1246548
# ..                     ...                     ...                  ...
# 995            KNKRNSMRKNK              KNKRNSMRKN          46876867468
# 996                MLSNKRS              MSNKS11111              6586478
# 997                MLSNKRS              MSNKS11111              6586478
# 998                MLSNKRS              MSNKS11111              6586478
# 999                MLSNKRS              MSNKS11111              6586478
#
#     NLP_fingerprint_positionfreq NLP_fingerprint_consonant  \
# 0                           WOVS                  WT SRVCS
# 1                           IMDN             IMPRL FD, NC.
# 2                           CLNC             CLPS MRCS NC.
# 3                           LANM    LNGNSCHDT PBLCTNS NGRM
# 4                           BOYD               BYD TCHNLGS
# ..                           ...                       ...
# 995                         KONC           KNCRNS MRC, NC.
# 996                         MORS                  MLSN CRS
# 997                         MORS                  MLSN CRS
# 998                         MORS                  MLSN CRS
# 999                         MORS                  MLSN CRS
#
#             NLP_fingerprint_LCCutter NLP_fingerprint_BWTRLEF  \
# 0                       W66874785347           STISCVWOEE OR
# 1                    I47475354663563             .L,DCINOP R
# 2                  C5577636475337563                .OSC CNI
# 3    L364467344538783553385667564736     MSTRLCUISIHGNNCLE T
# 4                   B693843466564547                      SD
# ..                               ...                     ...
# 995             K6643736473647533563        .S,ACC RNIENMNR
# 996                      M6576636677                    SN O
# 997                      M6576636677                    SN O
# 998                      M6576636677                    SN O
# 999                      M6576636677                    SN O
#
#     NLP_fingerprint_LACSS
# 0                 8314792
# 1                 5220099
# 2                 3021707
# 3                 6007809
# 4                 2500774
# ..                    ...
# 995               5751380
# 996               6253461
# 997               6253461
# 998               6253461
# 999               6253461
#
# [1000 rows x 12 columns]

# %%
len(list(consignee_ALL_ER.keys()))
# Out:
# 4083

# %%
consignee_UNIQUE_ER = {}
for i, v in consignee_ALL_ER.items():
    v_nnz = zip(*v.nonzero())
    vh = hash(frozenset(v_nnz))
    consignee_UNIQUE_ER[vh] = [i] if vh not in consignee_UNIQUE_ER.keys() else consignee_UNIQUE_ER[vh] + [i]

# %%
len(list(consignee_UNIQUE_ER.keys()))
# Out:
# 86

# %%
type(a)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
a= consignee_ALL_ER['NLP_fingerprint_LACSS']
b= consignee_ALL_ER['NLP_fingerprint_BWTRLEF']
aa = [ list(elem) for elem in list(consignee_ALL_ER['NLP_fingerprint_LACSS']) ]
bb = [ list(elem) for elem in list(consignee_ALL_ER['NLP_fingerprint_BWTRLEF']) ]

# %%
type(a)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
len(list(a.intersection(b))) / len(list(a.union(b)))
#https://deepai.org/machine-learning-glossary-and-terms/jaccard-index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-f66cbdc28599> in <module>
# ----> 1 len(list(a.intersection(b))) / len(list(a.union(b)))
#       2 #https://deepai.org/machine-learning-glossary-and-terms/jaccard-index
#
# /opt/jupyterhub/lib/python3.7/site-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     689             return self.getnnz()
#     690         else:
# --> 691             raise AttributeError(attr + " not found")
#     692
#     693     def transpose(self, axes=None, copy=False):
#
# AttributeError: intersection not found

# %%
evaluate(aa,bb,'variation_of_information')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-33ba62a80998> in <module>
# ----> 1 evaluate(aa,bb,'variation_of_information')
#
# /opt/jupyterhub/lib/python3.7/site-packages/entity_resolution_evaluation/evaluation.py in evaluate(R, S, metric)
#     108         double : the value of the metric
#     109     """
# --> 110     check_r_s_same_size(R,S)
#     111     S_set = to_set(S)
#     112     N = len(S_set)
#
# /opt/jupyterhub/lib/python3.7/site-packages/entity_resolution_evaluation/evaluation.py in check_r_s_same_size(R, S)
#      69     for i, val in enumerate(R):
#      70         for j, rec in enumerate(val):
# ---> 71             R_set.add(rec)
#      72     for i, val in enumerate(S):
#      73         for j, rec in enumerate(val):
#
# TypeError: unhashable type: 'csr_matrix'

# %% [markdown]
# <img src="entity_metrics.PNG" width="800" height="400">

# %%
metrics = ['bmd','precision','recall','f1','variation_of_information']

results = {}
for er_hash, combination in consignee_UNIQUE_ER.items():
    
    results[er_hash] = { m:evaluate(set_partition(consignee_ALL_ER[combination[0]]),consignee_goldenER,m) for m in metrics}
    
results = pd.DataFrame.from_dict(results).transpose()
results
# Out:
#                        bmd  precision    recall        f1  \
# -6193327702797796591  32.0   0.807692  1.000000  0.893617
# -6141876134287074174  12.0   1.000000  0.958730  0.978930
# -613699151210294997    4.0   1.000000  0.984127  0.992000
# -2967526185321071585  11.0   1.000000  0.961905  0.980583
#  1194780099854449836   3.0   1.000000  0.987302  0.993610
# ...                    ...        ...       ...       ...
#  6349580182836644931   4.0   0.996795  0.987302  0.992026
# -5611511134012889664   3.0   0.996805  0.990476  0.993631
#  6255416303574597041   8.0   0.981132  0.990476  0.985782
# -3769901920257834251   9.0   0.891429  0.990476  0.938346
# -3409031282546758041  13.0   0.881356  0.990476  0.932735
#
#                       variation_of_information
# -6193327702797796591                  0.055479
# -6141876134287074174                  0.017159
# -613699151210294997                   0.006068
# -2967526185321071585                  0.015772
#  1194780099854449836                  0.004682
# ...                                        ...
#  6349580182836644931                  0.006068
# -5611511134012889664                  0.004682
#  6255416303574597041                  0.011614
# -3769901920257834251                  0.019252
# -3409031282546758041                  0.024797
#
# [86 rows x 5 columns]

# %%
results[results['bmd'] == results['bmd'].min()]

# %%
results[results['variation_of_information'] == results['variation_of_information'].min()]

# %%
results[results['precision'] == results['precision'].max()]

# %%
results[results['recall'] == results['recall'].max()]

# %%
results[results['f1'] == results['f1'].max()]

# %%
consignee_UNIQUE_ER[8658760148384774510]

# %%
consignee_UNIQUE_ER[-8672847595432865152]

# %%
test = pd.DataFrame({0:['a','b','c','d','b','a'], 1:['a','b','c','d','e','f']})
print(test)
test = create_matrices(test, [0,1])

# %%
#operation = consignee_matrices['name_consignee'] * consignee_matrices['NLP_stem']

operation = 1
for m in test.values():
    operation *= m
operation

# %%
operation

# %%
partition

# %%
#consignee_matrices = 
# %timeit create_matrices(consignee, ['name_consignee','NLP_stem'])

# %%
consignee_matrices['name_consignee']
